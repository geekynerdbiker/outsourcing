# %%
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.models import load_model
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/MyDrive')

# %%
filename = 'sample_image.png'
img = load_img(filename, target_size=(150, 150))
plt.imshow(img)

# %%
img = img_to_array(img)
print(img.shape)
print(img)
# Out:
# (150, 150, 3)
# [[[123. 123. 123.]
#   [150. 150. 150.]
#   [ 73.  73.  73.]
#   ...
#   [ 35.  35.  35.]
#   [ 88.  88.  88.]
#   [116. 116. 116.]]
#
#  [[107. 107. 107.]
#   [129. 129. 129.]
#   [ 78.  78.  78.]
#   ...
#   [ 66.  66.  66.]
#   [107. 107. 107.]
#   [123. 123. 123.]]
#
#  [[ 54.  54.  54.]
#   [ 36.  36.  36.]
#   [ 78.  78.  78.]
#   ...
#   [124. 124. 124.]
#   [ 40.  40.  40.]
#   [ 35.  35.  35.]]
#
#  ...
#
#  [[ 87.  87.  87.]
#   [102. 102. 102.]
#   [ 56.  56.  56.]
#   ...
#   [ 64.  64.  64.]
#   [ 60.  60.  60.]
#   [ 68.  68.  68.]]
#
#  [[120. 120. 120.]
#   [154. 154. 154.]
#   [ 98.  98.  98.]
#   ...
#   [ 45.  45.  45.]
#   [ 96.  96.  96.]
#   [156. 156. 156.]]
#
#  [[ 56.  56.  56.]
#   [ 40.  40.  40.]
#   [ 40.  40.  40.]
#   ...
#   [ 90.  90.  90.]
#   [ 63.  63.  63.]
#   [ 64.  64.  64.]]]

# %%
img = img.reshape(1, 150, 150, 3)
print(img.shape)
print(img)
# Out:
# (1, 150, 150, 3)
# [[[[123. 123. 123.]
#    [150. 150. 150.]
#    [ 73.  73.  73.]
#    ...
#    [ 35.  35.  35.]
#    [ 88.  88.  88.]
#    [116. 116. 116.]]
#
#   [[107. 107. 107.]
#    [129. 129. 129.]
#    [ 78.  78.  78.]
#    ...
#    [ 66.  66.  66.]
#    [107. 107. 107.]
#    [123. 123. 123.]]
#
#   [[ 54.  54.  54.]
#    [ 36.  36.  36.]
#    [ 78.  78.  78.]
#    ...
#    [124. 124. 124.]
#    [ 40.  40.  40.]
#    [ 35.  35.  35.]]
#
#   ...
#
#   [[ 87.  87.  87.]
#    [102. 102. 102.]
#    [ 56.  56.  56.]
#    ...
#    [ 64.  64.  64.]
#    [ 60.  60.  60.]
#    [ 68.  68.  68.]]
#
#   [[120. 120. 120.]
#    [154. 154. 154.]
#    [ 98.  98.  98.]
#    ...
#    [ 45.  45.  45.]
#    [ 96.  96.  96.]
#    [156. 156. 156.]]
#
#   [[ 56.  56.  56.]
#    [ 40.  40.  40.]
#    [ 40.  40.  40.]
#    ...
#    [ 90.  90.  90.]
#    [ 63.  63.  63.]
#    [ 64.  64.  64.]]]]

# %%
models = ['VGG16.hdf5', 'VGG16_2.hdf5', 'InceptionV3.hdf5', 'InceptionV3_2.hdf5', 'MobileNet.hdf5', 'MobileNet_2.hdf5']
img = img.astype(float)/255.

for m in models:
  print('Model: ' + m)
  model= load_model('./model/'+m)
  result = model.predict(img)
  print(result)
  index = int(np.round(result))
  print(index)
  labels = ['FAIL', 'OK']
  print(labels[index])
  print()
# Out:
# Model: VGG16.hdf5
# 1/1 [==============================] - 0s 265ms/step
# [[0.9923868]]
# 1
# OK
#
# Model: VGG16_2.hdf5
# 1/1 [==============================] - 0s 264ms/step
# [[0.98883593]]
# 1
# OK
#
# Model: InceptionV3.hdf5
# 1/1 [==============================] - 1s 1s/step
# [[0.94550526]]
# 1
# OK
#
# Model: InceptionV3_2.hdf5
# WARNING:tensorflow:5 out of the last 5 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3e5ff439a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 998ms/step
# [[0.95145714]]
# 1
# OK
#
# Model: MobileNet.hdf5
# WARNING:tensorflow:6 out of the last 6 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7f3e5e45a560> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 1s 1s/step
# [[0.9891042]]
# 1
# OK
#
# Model: MobileNet_2.hdf5
# 1/1 [==============================] - 1s 1s/step
# [[0.8611271]]
# 1
# OK
