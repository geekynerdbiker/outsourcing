# %%
import pandas as pd
import matplotlib.pyplot as plt

# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /usr/share/fonts/truetype: skipping, looped directory detected
# /usr/share/fonts/truetype/humor-sans: skipping, looped directory detected
# ...

# %%
df = pd.read_csv('dataset.csv', encoding='cp949')
df.head()
# Out:
#              축제명                 개최장소      축제시작일자      축제종료일자  \
# 0         강릉커피축제         강릉대도호부 관아지 등  2022-10-06  2022-10-09
# 1  전국생활문화축제 in강릉             강릉명주예술마당  2022-10-27  2022-10-30
# 2    2022 강릉와인축제  강릉 월화거리 일원(문선빌딩 방면)  2022-12-09  2022-12-11
# 3    2022 강릉누들축제  강릉 월화거리 일원(홈플러스 방면)  2022-12-16  2022-12-18
# 4     군위 삼장군단오축제   효령면 고지바위권역다목적센터 일원  2022-06-03  2022-06-03
#
#                                                 축제내용     주관기관명     주최기관명  \
# 0  커피경연대회(바리스타+핸드드립+커핑+마카롱)+커피체험(로스팅+추출+커핑+공예품 등)...    강릉문화재단  강원도 강릉시청
# 1                            전국 생활문화 활동 발표+기획 프로그램 등    강릉문화재단  강원도 강릉시청
# 2                        도전 와인 골든벨+선셋 와인 아워+시음존 등 운영    강릉문화재단  강원도 강릉시청
# 3                   누들 쿠킹쇼, 쿠킹클래스, 시식회, 대형 수제비 만들기 등  강원도 강릉시청  강원도 강릉시청
# 4                                               단오축제     군위문화원     군위문화원
#
#                후원기관명          전화번호  \
# 0       문화체육관광부+강원도청  033-647-6802
# 1            지역문화진흥원  033-647-6808
# 2               강원도청  033-647-6802
# ...

# %%
df2 = df.loc[:, ['축제명', '개최장소', '축제내용', '주관기관명', '주최기관명', '소재지도로명주소', '제공기관명']].dropna()
df2.shape
# Out:
# (1467, 7)

# %%
grouped = df2.groupby('주최기관명')
grouped.first()
# Out:
#                                            축제명                  개최장소  \
# 주최기관명
# (공모예정)                              대구 문화유산 야행                  경상감영
# (사) 부산국제영화제                        부산국제영화제 전야제              BIFF광장일원
# (사)강릉단오제위원회+(사)강릉단오제보존회                  강릉단오제   강릉시 남대천 단오장 및 지정행사장
# (사)강원민예총                 2020 강원민족예술한마당 끽해야 한판        춘천 공지천 의암공원 일원
# (사)강원민예총 삼척지부                          삼척민족예술제             문화예술회관 일원
# ...                                        ...                   ...
# 황연동, 황연동주민자치위원회                        태백 커플축제       통리 태양의 후예 공원 일원
# 횡성회다지소리전승보존회                         횡성회다지소리축제  횡성정금민속관 및 회다지소리문화체험관
# 효돈동연합청년회                           제19회 쇠소깍 축제           하효항과 쇠소깍 일대
# 휴애리자연생활공원                          휴애리 유럽 수국축제            휴애리 자연생활공원
# 흥선청소년문화의집                 청소년 문화 예술의 밤 흥선비긴어게인                 평화의광장
#
#                                                                       축제내용  \
# 주최기관명
# ...

# %%
grouped = df2.groupby('주관기관명')
grouped.first()
# Out:
#                                           축제명  \
# 주관기관명
# (공모예정)                             대구 문화유산 야행
# (사) 부산국제영화제                       부산국제영화제 전야제
# (사) 춘천마임축제                             춘천마임축제
# (사)가야문화축제제전위원회                     가야문화축제(예정)
# (사)강릉단오제위원회+(사)강릉단오제보존회             강릉단오제 본행사
# ...                                       ...
# 횡성회다지소리축제위원회                        횡성회다지소리축제
# 효돈동연합청년회                          제19회 쇠소깍 축제
# 휴애리자연생활공원                         휴애리 유럽 수국축제
# 흥부제전위원회                                   흥부제
# 흥선청소년문화의집                청소년 문화 예술의 밤 흥선비긴어게인
#
#                                                                       개최장소  \
# 주관기관명
# (공모예정)                                                                경상감영
# (사) 부산국제영화제                                                       BIFF광장일원
# (사) 춘천마임축제               춘청 중앙로+커먼즈필드 춘천+함악산 호수 케이블카 공영주차장 일원+축제극장 몸짓+춘...
# (사)가야문화축제제전위원회                                        수릉원+대성동 고분군+가야의거리 일원
# ...

# %%
grouped = df2.groupby('제공기관명')
grouped.first()
# Out:
#                       축제명                 개최장소  \
# 제공기관명
# 강원도 강릉시            강릉커피축제         강릉대도호부 관아지 등
# 강원도 고성군   고성군민의 날 및 수성문화제        고성종합운동장외 부대시설
# 강원도 동해시             동해무릉제            동해웰빙레포츠타운
# 강원도 삼척시          삼척정월대보름제                우체국일원
# 강원도 양구군      도솔산지구전투 전승행사               도솔산전적비
# ...                   ...                  ...
# 충청북도 증평군          증평들노래축제            증평민속체험박물관
# 충청북도 진천군        생거진천농다리축제  충청북도 진천군 문백면 농다리 일원
# 충청북도 청주시            직지문화제            고인쇄박물관 일원
# 충청북도 충주시       충주 다이브페스티벌              충주종합운동장
# 한국관광공사             정선아리랑제             정선 공설운동장
#
#                                                        축제내용           주관기관명  \
# 제공기관명
# 강원도 강릉시   커피경연대회(바리스타+핸드드립+커핑+마카롱)+커피체험(로스팅+추출+커핑+공예품 등)...          강릉문화재단
# 강원도 고성군                                       수성제례+군민의 날 행사           고성문화원
# 강원도 동해시                  개막식+퍼레이드+공연행사+체험행사+동대항 민속경기+민속예술시연        동해문화관광재단
# ...

# %%
for key, group in grouped:
  print("KEY:", str(key))
  print("GROUP:", len(group))
  print(group.head())
  print("\n\n")
# Out:
# KEY: 강원도 강릉시
# GROUP: 7
#                축제명                 개최장소  \
# 0           강릉커피축제         강릉대도호부 관아지 등
# 1    전국생활문화축제 in강릉             강릉명주예술마당
# 2      2022 강릉와인축제  강릉 월화거리 일원(문선빌딩 방면)
# 3      2022 강릉누들축제  강릉 월화거리 일원(홈플러스 방면)
# 255  제23회 정동진독립영화제           정동초등학교 운동장
#
#                                                   축제내용                주관기관명  \
# 0    커피경연대회(바리스타+핸드드립+커핑+마카롱)+커피체험(로스팅+추출+커핑+공예품 등)...               강릉문화재단
# 1                              전국 생활문화 활동 발표+기획 프로그램 등               강릉문화재단
# 2                          도전 와인 골든벨+선셋 와인 아워+시음존 등 운영               강릉문화재단
# 3                     누들 쿠킹쇼, 쿠킹클래스, 시식회, 대형 수제비 만들기 등             강원도 강릉시청
# 255                  야외 독립영화제(슬로건: 별이 지는 하늘 영화가 뜨는 바다)  제23회 정동진독립영화제 집행위원회
#
#                주최기관명                  소재지도로명주소    제공기관명
# 0           강원도 강릉시청  강원도 강릉시 임영로131번길 6 (용강동)  강원도 강릉시
# 1           강원도 강릉시청     강원도 강릉시 경강로 2021번길9-1  강원도 강릉시
# 2           강원도 강릉시청          강원도 강릉시 경강로 2111  강원도 강릉시
# ...

# %%
for key, val in grouped.groups.items():
  print(key)
# Out:
# 강원도 강릉시
# 강원도 고성군
# 강원도 동해시
# 강원도 삼척시
# 강원도 양구군
# 강원도 영월군
# 강원도 원주시
# 강원도 정선군
# 강원도 철원군
# 강원도 춘천시
# 강원도 태백시
# 강원도 평창군
# 강원도 홍천군
# 강원도 화천군
# 강원도 횡성군
# 강원특별자치도 강릉시
# 강원특별자치도 고성군
# 강원특별자치도 삼척시
# 강원특별자치도 영월군
# 강원특별자치도 원주시
# 강원특별자치도 정선군
# 강원특별자치도 철원군
# 강원특별자치도 춘천시
# 강원특별자치도 태백시
# 강원특별자치도 평창군
# 강원특별자치도 홍천군
# 강원특별자치도 화천군
# 강원특별자치도 횡성군
# 경기도 가평군
# 경기도 고양시
# 경기도 과천시
# 경기도 광명시
# 경기도 광주시
# 경기도 구리시
# 경기도 군포시
# 경기도 남양주시
# 경기도 동두천시
# 경기도 부천시
# 경기도 성남시
# 경기도 수원시
# 경기도 시흥시
# 경기도 안산시
# 경기도 안성시
# 경기도 안양시
# 경기도 양주시
# 경기도 양평군
# 경기도 여주시
# 경기도 연천군
# 경기도 오산시
# 경기도 용인시
# 경기도 의왕시
# 경기도 의정부시
# 경기도 이천시
# 경기도 파주시
# 경기도 평택시
# 경기도 포천시
# 경기도 하남시
# 경기도 화성시
# 경상남도 거제시
# 경상남도 거창군
# 경상남도 고성군
# 경상남도 김해시
# 경상남도 남해군
# 경상남도 밀양시
# 경상남도 사천시
# 경상남도 산청군
# 경상남도 양산시
# 경상남도 의령군
# 경상남도 진주시
# 경상남도 창녕군
# 경상남도 창원시
# 경상남도 통영시
# 경상남도 하동군
# 경상남도 함양군
# 경상남도 합천군
# 경상북도 경산시
# 경상북도 경주시
# 경상북도 고령군
# 경상북도 구미시
# 경상북도 군위군
# 경상북도 김천시
# 경상북도 문경시
# 경상북도 성주군
# 경상북도 안동시
# 경상북도 영양군
# 경상북도 영주시
# 경상북도 영천시
# 경상북도 예천군
# 경상북도 울릉군
# 경상북도 울진군
# 경상북도 의성군
# ...

# %%
df2['제공기관명'] = df2['제공기관명'].apply(lambda x: x.split()[0])
df2.groupby('제공기관명').size()
# Out:
# 제공기관명
# 강원도        261
# 강원특별자치도     76
# 경기도        191
# 경상남도        86
# 경상북도        36
# 광주광역시       18
# 대구광역시      100
# 대전광역시        5
# 부산광역시       54
# 서울특별시       97
# 세종특별자치시      2
# 울산광역시       31
# 인천광역시       28
# 전라남도        71
# 전라북도        40
# 전북특별자치도     26
# 제주특별자치도    151
# 충청남도        77
# 충청북도        55
# 한국관광공사      62
# dtype: int64

# %%
grouped = df2.groupby('제공기관명')
plt.figure(figsize=(23,5))
plt.bar(grouped.size().index, grouped.size())
plt.show()

# %%
group_sizes = grouped.size().sort_values(ascending=False)
top_5_groups = group_sizes.head(5).index
top_5_grouped_data = {group: grouped.get_group(group) for group in top_5_groups}

for group, data in top_5_grouped_data.items():
    print(f"Group: {group}")
    print(data.head())
    print("\n")
# Out:
# Group: 강원도
#               축제명                                 개최장소  \
# 0          강릉커피축제                         강릉대도호부 관아지 등
# 1   전국생활문화축제 in강릉                             강릉명주예술마당
# 2     2022 강릉와인축제                  강릉 월화거리 일원(문선빌딩 방면)
# 3     2022 강릉누들축제                  강릉 월화거리 일원(홈플러스 방면)
# 11    보이지 않아도 보이는  KT&G 상상마당 춘천 1전시실+KT&G 상상마당 춘천 2전시실
#
#                                                  축제내용     주관기관명  \
# 0   커피경연대회(바리스타+핸드드립+커핑+마카롱)+커피체험(로스팅+추출+커핑+공예품 등)...    강릉문화재단
# 1                             전국 생활문화 활동 발표+기획 프로그램 등    강릉문화재단
# 2                         도전 와인 골든벨+선셋 와인 아워+시음존 등 운영    강릉문화재단
# 3                    누들 쿠킹쇼, 쿠킹클래스, 시식회, 대형 수제비 만들기 등  강원도 강릉시청
# 11  전시장에서 작품을 관람하고자 할 때, 종종 만지지 마세요 눈으로만 보세요.’ 라는 ...  공공미터협동조합
#
#               주최기관명                      소재지도로명주소 제공기관명
# 0          강원도 강릉시청      강원도 강릉시 임영로131번길 6 (용강동)   강원도
# 1          강원도 강릉시청         강원도 강릉시 경강로 2021번길9-1   강원도
# 2          강원도 강릉시청              강원도 강릉시 경강로 2111   강원도
# ...

# %%
from collections import Counter
import re

group_word_counts = {}
for group, data in top_5_grouped_data.items():
    print(f"Group: {group}")
    combined_text = data['축제명'] + ' ' + data['축제내용']
    all_text = ' '.join(combined_text)
    words = re.findall(r'\b\w+\b', all_text)
    word_counts = Counter(words)
    print(word_counts)
    group_word_counts[group] = word_counts
# Out:
# Group: 강원도
# ...

# %%
import numpy as np

class BubbleChart:
    def __init__(self, area, bubble_spacing=0):
        """
        Setup for bubble collapse.

        Parameters
        ----------
        area : array-like
            Area of the bubbles.
        bubble_spacing : float, default: 0
            Minimal spacing between bubbles after collapsing.

        Notes
        -----
        If "area" is sorted, the results might look weird.
        """
        area = np.asarray(area)
        r = np.sqrt(area / np.pi)

        self.bubble_spacing = bubble_spacing
        self.bubbles = np.ones((len(area), 4))
        self.bubbles[:, 2] = r
        self.bubbles[:, 3] = area
        self.maxstep = 2 * self.bubbles[:, 2].max() + self.bubble_spacing
        self.step_dist = self.maxstep / 2

        # calculate initial grid layout for bubbles
        length = np.ceil(np.sqrt(len(self.bubbles)))
        grid = np.arange(length) * self.maxstep
        gx, gy = np.meshgrid(grid, grid)
        self.bubbles[:, 0] = gx.flatten()[:len(self.bubbles)]
        self.bubbles[:, 1] = gy.flatten()[:len(self.bubbles)]

        self.com = self.center_of_mass()

    def center_of_mass(self):
        return np.average(
            self.bubbles[:, :2], axis=0, weights=self.bubbles[:, 3]
        )

    def center_distance(self, bubble, bubbles):
        return np.hypot(bubble[0] - bubbles[:, 0],
                        bubble[1] - bubbles[:, 1])

    def outline_distance(self, bubble, bubbles):
        center_distance = self.center_distance(bubble, bubbles)
        return center_distance - bubble[2] - \
            bubbles[:, 2] - self.bubble_spacing

    def check_collisions(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return len(distance[distance < 0])

    def collides_with(self, bubble, bubbles):
        distance = self.outline_distance(bubble, bubbles)
        return np.argmin(distance, keepdims=True)

    def collapse(self, n_iterations=50):
        """
        Move bubbles to the center of mass.

        Parameters
        ----------
        n_iterations : int, default: 50
            Number of moves to perform.
        """
        for _i in range(n_iterations):
            moves = 0
            for i in range(len(self.bubbles)):
                rest_bub = np.delete(self.bubbles, i, 0)
                # try to move directly towards the center of mass
                # direction vector from bubble to the center of mass
                dir_vec = self.com - self.bubbles[i, :2]

                # shorten direction vector to have length of 1
                dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))

                # calculate new bubble position
                new_point = self.bubbles[i, :2] + dir_vec * self.step_dist
                new_bubble = np.append(new_point, self.bubbles[i, 2:4])

                # check whether new bubble collides with other bubbles
                if not self.check_collisions(new_bubble, rest_bub):
                    self.bubbles[i, :] = new_bubble
                    self.com = self.center_of_mass()
                    moves += 1
                else:
                    # try to move around a bubble that you collide with
                    # find colliding bubble
                    for colliding in self.collides_with(new_bubble, rest_bub):
                        # calculate direction vector
                        dir_vec = rest_bub[colliding, :2] - self.bubbles[i, :2]
                        dir_vec = dir_vec / np.sqrt(dir_vec.dot(dir_vec))
                        # calculate orthogonal vector
                        orth = np.array([dir_vec[1], -dir_vec[0]])
                        # test which direction to go
                        new_point1 = (self.bubbles[i, :2] + orth *
                                      self.step_dist)
                        new_point2 = (self.bubbles[i, :2] - orth *
                                      self.step_dist)
                        dist1 = self.center_distance(
                            self.com, np.array([new_point1]))
                        dist2 = self.center_distance(
                            self.com, np.array([new_point2]))
                        new_point = new_point1 if dist1 < dist2 else new_point2
                        new_bubble = np.append(new_point, self.bubbles[i, 2:4])
                        if not self.check_collisions(new_bubble, rest_bub):
                            self.bubbles[i, :] = new_bubble
                            self.com = self.center_of_mass()

            if moves / len(self.bubbles) < 0.1:
                self.step_dist = self.step_dist / 2

    def plot(self, ax, labels, colors):
        """
        Draw the bubble plot.

        Parameters
        ----------
        ax : matplotlib.axes.Axes
        labels : list
            Labels of the bubbles.
        colors : list
            Colors of the bubbles.
        """
        for i in range(len(self.bubbles)):
            circ = plt.Circle(
                self.bubbles[i, :2], self.bubbles[i, 2], color=colors[i])
            ax.add_patch(circ)
            ax.text(*self.bubbles[i, :2], labels[i],
                    horizontalalignment='center', verticalalignment='center')

# %%
def bubble_chart(group, keys, values):
  colors = ['#5A69AF', '#579E65', '#F9C784', '#FC944A', '#F24C00', '#00B825', '#597AB5', '#549D73', '#F7C28F', '#FC9D5B', '#5A69AF', '#579E65', '#F9C784', '#FC944A', '#F24C00', '#00B825', '#597AB5', '#549D73', '#F7C28F', '#FC9D5B']
  bubble_chart = BubbleChart(area=values,
                           bubble_spacing=0.1)

  bubble_chart.collapse()

  fig, ax = plt.subplots(subplot_kw=dict(aspect="equal"))
  bubble_chart.plot(ax, keys, colors)
  ax.axis("off")
  ax.relim()
  ax.autoscale_view()
  ax.set_title(group)

  plt.show()

# %%
for group, word_counts in group_word_counts.items():
    common_words = word_counts.most_common(20)
    words, counts = zip(*common_words)
    bubble_chart(group, words, counts)
