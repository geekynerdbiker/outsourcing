# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
from tensorflow.keras.utils import to_categorical, plot_model

# %%
from tensorflow.keras.datasets import cifar10
import numpy as np
(x_train,y_train),(x_test,y_test)=cifar10.load_data()

x_train = x_train/255.
x_test = x_test/255.

num_classes = 10 

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

# %%
model = Sequential()

# first block
model.add(Conv2D(16,3, activation='relu', padding='same',input_shape=(32,32, 3)))
model.add(Conv2D(16,3, activation='relu', padding='same'))
model.add(MaxPool2D(2))

# second block
model.add(Conv2D(filters=32,kernel_size=3, activation='relu', padding='same'))
model.add(Conv2D(filters=32, kernel_size=3, activation='relu', padding='same'))
model.add(MaxPool2D(2))

# third block
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# forth block
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# fifth block
#model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
#model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
#model.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
#model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))

# sixth block (classifier)
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 32, 32, 16)        448
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 16)        2320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 16, 16, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 32)        4640
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 16, 16, 32)        9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 8, 8, 32)          0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 64)          18496
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 128)         73856
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 4, 4, 128)         147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 256)               131328
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 677,722
# Trainable params: 677,722
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lr_scheduler=ReduceLROnPlateau(monitor='val_loss', factor=np.sqrt(0.1))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


hist = model.fit(x_train, y_train, batch_size=128, epochs=50,
          validation_data=(x_test, y_test), callbacks=[lr_scheduler])
# Out:
# Epoch 1/50
# 391/391 [==============================] - 62s 156ms/step - loss: 2.0693 - accuracy: 0.2013 - val_loss: 1.5943 - val_accuracy: 0.3782
# Epoch 2/50
# 391/391 [==============================] - 70s 179ms/step - loss: 1.5975 - accuracy: 0.3905 - val_loss: 1.3970 - val_accuracy: 0.4839
# Epoch 3/50
# 391/391 [==============================] - 105s 269ms/step - loss: 1.3390 - accuracy: 0.5130 - val_loss: 1.1717 - val_accuracy: 0.5811
# Epoch 4/50
# 391/391 [==============================] - 76s 195ms/step - loss: 1.1523 - accuracy: 0.5894 - val_loss: 1.0720 - val_accuracy: 0.6200
# Epoch 5/50
# 391/391 [==============================] - 89s 226ms/step - loss: 1.0129 - accuracy: 0.6465 - val_loss: 0.9539 - val_accuracy: 0.6650
# Epoch 6/50
# 391/391 [==============================] - 95s 242ms/step - loss: 0.9190 - accuracy: 0.6790 - val_loss: 0.9231 - val_accuracy: 0.6759
# Epoch 7/50
# 391/391 [==============================] - 75s 192ms/step - loss: 0.8461 - accuracy: 0.7085 - val_loss: 0.8757 - val_accuracy: 0.6986
# Epoch 8/50
# 391/391 [==============================] - 94s 241ms/step - loss: 0.7637 - accuracy: 0.7370 - val_loss: 0.9034 - val_accuracy: 0.6939
# Epoch 9/50
# 391/391 [==============================] - 74s 189ms/step - loss: 0.6973 - accuracy: 0.7621 - val_loss: 0.8506 - val_accuracy: 0.7061
# Epoch 10/50
# 391/391 [==============================] - 87s 222ms/step - loss: 0.6537 - accuracy: 0.7731 - val_loss: 0.9006 - val_accuracy: 0.7054
# Epoch 11/50
# 391/391 [==============================] - 90s 231ms/step - loss: 0.6025 - accuracy: 0.7933 - val_loss: 0.8676 - val_accuracy: 0.7093
# Epoch 12/50
# 391/391 [==============================] - 73s 187ms/step - loss: 0.5624 - accuracy: 0.8065 - val_loss: 0.8327 - val_accuracy: 0.7311
# Epoch 13/50
# 391/391 [==============================] - 93s 238ms/step - loss: 0.5166 - accuracy: 0.8208 - val_loss: 0.8586 - val_accuracy: 0.7247
# Epoch 14/50
# 391/391 [==============================] - 85s 218ms/step - loss: 0.4679 - accuracy: 0.8419 - val_loss: 0.9095 - val_accuracy: 0.7172
# Epoch 15/50
# 391/391 [==============================] - 91s 232ms/step - loss: 0.4666 - accuracy: 0.8427 - val_loss: 0.9169 - val_accuracy: 0.7258
# Epoch 16/50
# 391/391 [==============================] - 94s 241ms/step - loss: 0.3988 - accuracy: 0.8638 - val_loss: 0.8790 - val_accuracy: 0.7266
# Epoch 17/50
# 391/391 [==============================] - 80s 205ms/step - loss: 0.3946 - accuracy: 0.8657 - val_loss: 0.9078 - val_accuracy: 0.7262
# Epoch 18/50
# 391/391 [==============================] - 87s 222ms/step - loss: 0.3690 - accuracy: 0.8763 - val_loss: 0.9249 - val_accuracy: 0.7303
# Epoch 19/50
# 391/391 [==============================] - 94s 239ms/step - loss: 0.3482 - accuracy: 0.8825 - val_loss: 1.0001 - val_accuracy: 0.7217
# Epoch 20/50
# 391/391 [==============================] - 80s 206ms/step - loss: 0.3504 - accuracy: 0.8811 - val_loss: 0.9776 - val_accuracy: 0.7310
# Epoch 21/50
# 391/391 [==============================] - 88s 224ms/step - loss: 0.3029 - accuracy: 0.8975 - val_loss: 0.9440 - val_accuracy: 0.7348
# Epoch 22/50
# 391/391 [==============================] - 96s 245ms/step - loss: 0.2788 - accuracy: 0.9048 - val_loss: 1.0551 - val_accuracy: 0.7247
# Epoch 23/50
# 391/391 [==============================] - 80s 205ms/step - loss: 0.1819 - accuracy: 0.9403 - val_loss: 1.2880 - val_accuracy: 0.7446
# Epoch 24/50
# 391/391 [==============================] - 88s 226ms/step - loss: 0.0883 - accuracy: 0.9718 - val_loss: 1.5337 - val_accuracy: 0.7397
# Epoch 25/50
# 391/391 [==============================] - 95s 243ms/step - loss: 0.0745 - accuracy: 0.9755 - val_loss: 1.7876 - val_accuracy: 0.7371
# Epoch 26/50
# 391/391 [==============================] - 80s 205ms/step - loss: 0.0556 - accuracy: 0.9821 - val_loss: 1.7459 - val_accuracy: 0.7417
# Epoch 27/50
# 391/391 [==============================] - 89s 229ms/step - loss: 0.0485 - accuracy: 0.9849 - val_loss: 1.9009 - val_accuracy: 0.7381
# Epoch 28/50
# 391/391 [==============================] - 83s 213ms/step - loss: 0.0466 - accuracy: 0.9848 - val_loss: 1.9421 - val_accuracy: 0.7391
# Epoch 29/50
# 391/391 [==============================] - 74s 190ms/step - loss: 0.0559 - accuracy: 0.9827 - val_loss: 1.8736 - val_accuracy: 0.7384
# Epoch 30/50
# 391/391 [==============================] - 87s 222ms/step - loss: 0.0371 - accuracy: 0.9880 - val_loss: 2.0289 - val_accuracy: 0.7422
# Epoch 31/50
# 391/391 [==============================] - 74s 188ms/step - loss: 0.0394 - accuracy: 0.9881 - val_loss: 2.0433 - val_accuracy: 0.7404
# Epoch 32/50
# 391/391 [==============================] - 84s 214ms/step - loss: 0.0345 - accuracy: 0.9893 - val_loss: 2.2219 - val_accuracy: 0.7338
# Epoch 33/50
# 391/391 [==============================] - 74s 189ms/step - loss: 0.0193 - accuracy: 0.9937 - val_loss: 2.3270 - val_accuracy: 0.7437
# Epoch 34/50
# 391/391 [==============================] - 86s 221ms/step - loss: 0.0065 - accuracy: 0.9982 - val_loss: 2.5159 - val_accuracy: 0.7423
# Epoch 35/50
# 391/391 [==============================] - 71s 182ms/step - loss: 0.0032 - accuracy: 0.9993 - val_loss: 2.6298 - val_accuracy: 0.7453
# Epoch 36/50
# 391/391 [==============================] - 88s 225ms/step - loss: 0.0023 - accuracy: 0.9997 - val_loss: 2.8149 - val_accuracy: 0.7435
# Epoch 37/50
# 391/391 [==============================] - 71s 183ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 2.9868 - val_accuracy: 0.7441
# Epoch 38/50
# 391/391 [==============================] - 86s 220ms/step - loss: 0.0068 - accuracy: 0.9981 - val_loss: 2.9422 - val_accuracy: 0.7438
# Epoch 39/50
#  49/391 [==>...........................] - ETA: 1:18 - loss: 0.0030 - accuracy: 0.9996

# %% [markdown]
# ## VGG-19 (configuration E)

# %%
vgg_19 = Sequential()

# first block
vgg_19.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same',input_shape=(224,224, 3)))
vgg_19.add(Conv2D(filters=64, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# second block
vgg_19.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=128, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# third block
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# forth block
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# fifth block
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(Conv2D(filters=512, kernel_size=(3,3), strides=(1,1), activation='relu', padding='same'))
vgg_19.add(MaxPool2D((2,2), strides=(2,2)))

# seventh block (classifier)
vgg_19.add(Flatten())
vgg_19.add(Dense(4096, activation='relu'))
vgg_19.add(Dropout(0.5))
vgg_19.add(Dense(4096, activation='relu'))
vgg_19.add(Dropout(0.5))
vgg_19.add(Dense(1000, activation='softmax'))

vgg_19.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 224, 224, 64)      1792
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 224, 224, 64)      36928
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 112, 112, 128)     73856
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 112, 112, 128)     147584
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 56, 56, 256)       295168
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 56, 56, 256)       590080
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 28, 28, 256)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 28, 28, 512)       1180160
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 28, 28, 512)       2359808
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 14, 14, 512)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 14, 14, 512)       2359808
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 25088)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4096)              102764544
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 4096)              16781312
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4096)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1000)              4097000
# =================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# _________________________________________________________________
